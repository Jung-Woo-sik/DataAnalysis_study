# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40])

# %%
plt.plot([1,2,3,4],[12,34,25,15])

# %%
plt.title('plot title')
plt.plot([10,20,30,40])

# %%
plt.title('plot legend')
plt.plot([10,20,30,40],label='asc')
plt.plot([40,30,20,10],label='desc')
plt.legend()

# %%
plt.title('plot color')
plt.plot([10,20,30,40],color='skyblue',label='skyblue')
plt.plot([40,30,20,10],'pink',label='pink')
plt.legend()

# %%
plt.title('plot style')
plt.plot([10,20,30,40],color='r',linestyle='--',label='dashed')
plt.plot([40,30,20,10],'g',ls=':',label='dotted')
plt.legend()

# %%
plt.title('plot marksr')
plt.plot([10,20,30,40],'r.',label='circle')
plt.plot([40,30,20,10],'g^',label='triangle up')
plt.legend()

# %%
import csv

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)
result = []
for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))

# %%
len(result)#데이터의 개수
# Out:
# 40433

# %%
plt.plot(result,'r')#최고기온 시각화

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)
high = []
low = []

for row in data:
    if row[-1] != '' and row[-2] !='':
        data = row[0].split('-')
        if 1994 <= int(data[0]):
            if data[1] == '08' and data[2] =='14':
                high.append(float(row[-1]))
                low.append(float(row[-2]))
                
plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title("내 생일의 기온 변화")
plt.plot(high,'hotpink',label='high')
plt.plot(low,'skyblue',label='low')
plt.legend()
plt.show()

# %%
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
# Out:
# (array([2., 1., 1., 1., 1., 2., 1., 1., 0., 1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
import random
print(random.randint(1,6))# 주사위 던지기
# Out:
# 6

# %%
dice = []
for i in range(5):
    dice.append(random.randint(1,6))
plt.hist(dice,bins=6)
# Out:
# (array([2., 0., 0., 1., 1., 1.]),
#  array([1.        , 1.66666667, 2.33333333, 3.        , 3.66666667,
#         4.33333333, 5.        ]),
#  <BarContainer object of 6 artists>)

# %%
dice = []
for i in range(100):
    dice.append(random.randint(1,6))
plt.hist(dice,bins=6)
# Out:
# (array([18., 18., 13., 12., 19., 20.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)

# %%
dice = []
for i in range(100000):
    dice.append(random.randint(1,6))
plt.hist(dice,bins=6)
# Out:
# (array([16809., 16511., 16718., 16726., 16544., 16692.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)
result =[]

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
plt.hist(result,bins=100,color='r')
# Out:
# (array([1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 2.000e+00,
#         4.000e+00, 5.000e+00, 9.000e+00, 1.100e+01, 2.400e+01, 1.500e+01,
#         3.900e+01, 3.700e+01, 5.100e+01, 5.100e+01, 7.500e+01, 7.200e+01,
#         1.110e+02, 1.190e+02, 1.780e+02, 1.530e+02, 2.270e+02, 2.240e+02,
#         2.290e+02, 3.060e+02, 2.580e+02, 3.850e+02, 4.270e+02, 4.050e+02,
#         4.770e+02, 4.520e+02, 5.350e+02, 5.210e+02, 5.360e+02, 5.920e+02,
#         5.460e+02, 6.260e+02, 6.480e+02, 4.920e+02, 6.550e+02, 5.010e+02,
#         5.690e+02, 5.050e+02, 5.840e+02, 5.310e+02, 4.280e+02, 5.330e+02,
#         4.090e+02, 5.130e+02, 5.370e+02, 4.220e+02, 4.870e+02, 4.450e+02,
#         4.980e+02, 5.270e+02, 4.420e+02, 4.940e+02, 4.330e+02, 5.760e+02,
#         4.810e+02, 5.720e+02, 5.530e+02, 4.830e+02, 6.730e+02, 5.760e+02,
#         6.940e+02, 7.410e+02, 6.490e+02, 7.860e+02, 6.190e+02, 8.420e+02,
#         8.680e+02, 8.160e+02, 9.980e+02, 8.000e+02, 1.064e+03, 1.041e+03,
# ...

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)
aug =[]
jan = []
for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))
        
        if month == '01':
            jan.append(float(row[-1]))
plt.hist(aug,bins=100,color='r',label='aug')
plt.hist(jan,bins=100,color='b',label='jan')
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   1.,   0.,   0.,   2.,   0.,   2.,
#           0.,   3.,   1.,   5.,   1.,   4.,   7.,  13.,   7.,   6.,   4.,
#          14.,  13.,  12.,  12.,  19.,  17.,  32.,  18.,  27.,  26.,  26.,
#          22.,  44.,  40.,  44.,  42.,  36.,  54.,  46.,  47.,  71.,  61.,
#          49.,  65.,  56.,  65.,  82.,  73.,  87.,  79.,  76.,  93.,  82.,
#          89.,  86., 109.,  98.,  86.,  86.,  76., 101.,  88.,  70.,  90.,
#          70.,  74.,  59.,  80.,  56.,  73.,  42.,  54.,  40.,  59.,  45.,
#          37.,  24.,  28.,  22.,  16.,  16.,  17.,   6.,  15.,   4.,   5.,
#           5.,   4.,   4.,   4.,   5.,   4.,   0.,   1.,   2.,   1.,   2.,
#           1.]),
#  array([-16.3  , -15.993, -15.686, -15.379, -15.072, -14.765, -14.458,
#         -14.151, -13.844, -13.537, -13.23 , -12.923, -12.616, -12.309,
#         -12.002, -11.695, -11.388, -11.081, -10.774, -10.467, -10.16 ,
#          -9.853,  -9.546,  -9.239,  -8.932,  -8.625,  -8.318,  -8.011,
# ...

# %%
result = []
for i in range(13):
    result.append(random.randint(1,1000))
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [3, 95, 110, 110, 174, 399, 486, 598, 770, 772, 807, 878, 887]

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))

plt.boxplot(result)
plt.show()

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)
aug =[]
jan = []
for row in data:
    month = row[0].split('-')[1]
    if row[-1] != '':
        if month == '08':
            aug.append(float(row[-1]))
        
        if month == '01':
            jan.append(float(row[-1]))
            
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
plt.boxplot([aug,jan])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d8fb36be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d8fac6340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d8fb36820>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x22d8fac6a60>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x22d8fac6df0>,
# ...
#  'means': []}

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)

month = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data:
    if row[-1] != '':
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
plt.boxplot(month)
plt.show()

# %%
f = open('seoul.csv')#리스트에 최고 기온 저장
data = csv.reader(f)
next(data)
day = []
for i in range(31):
    day.append([])
    
for row in data:
    if row[-1] != '':
        if row[0].split('-')[1]=='08':
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))

plt.style.use('ggplot')
plt.figure(figsize=(10,5),dpi=300)
plt.boxplot(day,showfliers=False)

plt.show()
